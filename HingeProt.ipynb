# %% [markdown]
# <a href="https://colab.research.google.com/github/enesemretas/hingeprot_fortran/blob/main/HingeProt.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# @title HingeProt - User Interface (silent setup)

import os, sys, subprocess

def _run_quiet(cmd: str):
    subprocess.run(
        cmd,
        shell=True,
        check=True,
        stdout=subprocess.DEVNULL,
        stderr=subprocess.DEVNULL
    )

# Go to /content without printing it
os.chdir("/content")

# Clone repo quietly
_run_quiet("rm -rf hingeprot_fortran")
_run_quiet("git clone -q https://github.com/enesemretas/hingeprot_fortran.git")

# Launch interface (ui.py is inside hingeprot_fortran/hingeprot)
ui_dir = "/content/hingeprot_fortran/hingeprot"
if ui_dir not in sys.path:
    sys.path.insert(0, ui_dir)

from ui import launch
launch()
# Out:
# HTML(value='\n    <style>\n    .hp-card {border:1px solid #e5e7eb; border-radius:14px; padding:14px 16px; marg…
# HTML(value='\n    <div class="hp-banner">\n      <div class="hp-dot"></div>\n      <div>\n        <div class="…
# VBox(children=(HTML(value='<div class="hp-card">'), ToggleButtons(description='Input:', layout=Layout(width='4…
# VBox(children=(HTML(value='<div class="hp-card"><b>Status / Logs</b></div>'), HTML(value='<div class="hp-pre">…
# {'pdb_text': None,
#  'pdb_filename': None,
#  'pdb_path': None,
#  'run_dir': None,
#  'pdb_tag': None,
#  'upload_name': None,
#  'upload_bytes': None,
#  'detected_chains': [],
#  'chain_cbs': {},
#  'manual_selection': (),
#  '_syncing': False,
#  'inputs': None,
#  'hingeprot_dir': None,
#  'last_out_dir': None}
