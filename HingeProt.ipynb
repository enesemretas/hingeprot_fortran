# %% [markdown]
# <a href="https://colab.research.google.com/github/enesemretas/hingeprot_fortran/blob/main/HingeProt.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# get the old runtime packages (amd64) that contain libg2c.so.0
# !wget -q https://old-releases.ubuntu.com/ubuntu/pool/universe/g/gcc-3.4/gcc-3.4-base_3.4.6-6ubuntu3_amd64.deb
# !wget -q https://old-releases.ubuntu.com/ubuntu/pool/universe/g/gcc-3.4/libg2c0_3.4.6-6ubuntu3_amd64.deb

# install them
# !dpkg -i gcc-3.4-base_3.4.6-6ubuntu3_amd64.deb libg2c0_3.4.6-6ubuntu3_amd64.deb || true

# if dpkg reports missing deps, this will fix them automatically
# !apt-get -y -qq -f install

# refresh linker cache
# !ldconfig

# verify the library is now available
# !ldconfig -p | grep -E "libg2c\.so\.0" || true
# Out:
# (Reading database ... 117540 files and directories currently installed.)
# Preparing to unpack gcc-3.4-base_3.4.6-6ubuntu3_amd64.deb ...
# Unpacking gcc-3.4-base (3.4.6-6ubuntu3) over (3.4.6-6ubuntu3) ...
# Preparing to unpack libg2c0_3.4.6-6ubuntu3_amd64.deb ...
# Unpacking libg2c0 (1:3.4.6-6ubuntu3) over (1:3.4.6-6ubuntu3) ...
# Setting up gcc-3.4-base (3.4.6-6ubuntu3) ...
# Setting up libg2c0 (1:3.4.6-6ubuntu3) ...
# Processing triggers for libc-bin (2.35-0ubuntu3.11) ...
# /sbin/ldconfig.real: /usr/local/lib/libur_loader.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbb.so.12 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libhwloc.so.15 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_level_zero.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_0.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm_debug.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_level_zero_v2.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_opencl.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libumf.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc_proxy.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_5.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_loader.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbb.so.12 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libhwloc.so.15 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_level_zero.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_0.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm_debug.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_level_zero_v2.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_opencl.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libumf.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc_proxy.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_5.so.3 is not a symbolic link
#
# 	libg2c.so.0 (libc6,x86-64) => /lib/libg2c.so.0

# %%
# !git clone https://github.com/enesemretas/hingeprot_fortran.git
# Out:
# Cloning into 'hingeprot_fortran'...
# remote: Enumerating objects: 45, done.
# remote: Counting objects: 100% (45/45), done.
# remote: Compressing objects: 100% (40/40), done.
# remote: Total 45 (delta 15), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (45/45), 3.66 MiB | 5.20 MiB/s, done.
# Resolving deltas: 100% (15/15), done.

# %%
# 0) (opsiyonel) temiz başla
# %cd /content
# !rm -rf hingeprot_fortran

# 1) repo’yu çek
# !git clone https://github.com/enesemretas/hingeprot_fortran.git

# 2) doğru klasöre gir (EN kritik satır)
# %cd /content/hingeprot_fortran/hingeprot

# 3) içerik kontrolü
# !pwd
# !ls -lah
# Out:
# /content
# Cloning into 'hingeprot_fortran'...
# remote: Enumerating objects: 45, done.
# remote: Counting objects: 100% (45/45), done.
# remote: Compressing objects: 100% (40/40), done.
# remote: Total 45 (delta 15), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (45/45), 3.66 MiB | 5.25 MiB/s, done.
# Resolving deltas: 100% (15/15), done.
# /content/hingeprot_fortran/hingeprot
# /content/hingeprot_fortran/hingeprot
# total 11M
# drwxr-xr-x 2 root root 4.0K Jan 17 01:45 .
# drwxr-xr-x 4 root root 4.0K Jan 17 01:45 ..
# -rw-r--r-- 1 root root    1 Jan 17 01:45 deneme
# -rw-r--r-- 1 root root 3.6M Jan 17 01:45 getChain.Linux
# -rw-r--r-- 1 root root  55K Jan 17 01:45 part1
# -rw-r--r-- 1 root root  54K Jan 17 01:45 part2
# -rw-r--r-- 1 root root 6.3M Jan 17 01:45 processHinges
# -rw-r--r-- 1 root root 1.6K Jan 17 01:45 README
# -rw-r--r-- 1 root root  957 Jan 17 01:45 runHingeProt.pl
# -rw-r--r-- 1 root root 326K Jan 17 01:45 useblz

# %%
# !wget -q https://files.rcsb.org/download/4CLN.pdb -O 4cln.pdb
# !ls -lah 4cln.pdb
# Out:
# -rw-r--r-- 1 root root 142K Jan 17 01:46 4cln.pdb

# %%
# script + aynı klasördeki olası binary’lere execute izni
# !chmod +x ./runHingeProt.pl || true
# !find . -maxdepth 1 -type f -exec chmod +x {} \; || true

# çalıştır
# !perl ./runHingeProt.pl 4cln.pdb A

# çıktı kontrol (bu genelde bir klasör olur)
# !ls -lah
# !ls -lah 4cln.pdb.A || true
# Out:
# aaMol.size() = 148
# Input mode1: 1 hinges
# Input mode2: 10 hinges
# # of hinges: 1# of parts: 2
# # of clusters: 2
# Cluster : 1
# 1 -1-76
# Cluster : 2
# 1 76--1
# removing 53 54
# removing 55 56
# removing 138 139
# # of hinges: 4# of parts: 5
# score12 0.724724 s1 0.531807 s2 0.515306 part12score 0.203908 (score1 + score2)/2.0 0.523556
# Contact MAP: 0 -1-16 with 62-90
# EndPoints: 1 -1-16 with 62-90
# score12 0.774486 s1 0.531807 s2 0.850119 part12score 0 (score1 + score2)/2.0 0.690963
# Contact MAP: 0 -1-16 with 90-136
# EndPoints: 0 -1-16 with 90-136
# score12 0.473149 s1 0.531807 s2 0.39527 part12score 0 (score1 + score2)/2.0 0.463538
# Contact MAP: 0 -1-16 with 136--1
# EndPoints: 0 -1-16 with 136--1
# score12 0.853024 s1 0.855987 s2 0.850119 part12score 0 (score1 + score2)/2.0 0.853053
# Contact MAP: 0 16-62 with 90-136
# EndPoints: 0 16-62 with 90-136
# score12 0.766971 s1 0.855987 s2 0.39527 part12score 0 (score1 + score2)/2.0 0.625629
# Contact MAP: 0 16-62 with 136--1
# EndPoints: 0 16-62 with 136--1
# score12 0.608333 s1 0.515306 s2 0.39527 part12score 0.125926 (score1 + score2)/2.0 0.455288
# Contact MAP: 0 62-90 with 136--1
# EndPoints: 1 62-90 with 136--1
# # of clusters: 3
# Cluster : 1
# 2 -1-16
# 3 62-90
# 2 136--1
# Cluster : 2
# 1 16-62
# Cluster : 3
# 1 90-136
# total 11M
# drwxr-xr-x 3 root root 4.0K Jan 17 01:46 .
# drwxr-xr-x 4 root root 4.0K Jan 17 01:45 ..
# -rwxr-xr-x 1 root root 142K Jan 17 01:46 4cln.pdb
# drwxr-xr-x 2 root root 4.0K Jan 17 01:46 4cln.pdb.A
# -rwxr-xr-x 1 root root    1 Jan 17 01:45 deneme
# -rwxr-xr-x 1 root root 3.6M Jan 17 01:45 getChain.Linux
# -rwxr-xr-x 1 root root  55K Jan 17 01:45 part1
# -rwxr-xr-x 1 root root  54K Jan 17 01:45 part2
# -rwxr-xr-x 1 root root 6.3M Jan 17 01:45 processHinges
# -rwxr-xr-x 1 root root 1.6K Jan 17 01:45 README
# -rwxr-xr-x 1 root root  957 Jan 17 01:45 runHingeProt.pl
# -rwxr-xr-x 1 root root 326K Jan 17 01:45 useblz
# total 13M
# drwxr-xr-x 2 root root 4.0K Jan 17 01:46 .
# drwxr-xr-x 3 root root 4.0K Jan 17 01:46 ..
# -rw-r--r-- 1 root root 679K Jan 17 01:46 10anm.pdb
# -rw-r--r-- 1 root root 7.1K Jan 17 01:46 10coor
# -rw-r--r-- 1 root root 216K Jan 17 01:46 10cross
# -rw-r--r-- 1 root root 679K Jan 17 01:46 1anm.pdb
# -rw-r--r-- 1 root root 7.1K Jan 17 01:46 1coor
# -rw-r--r-- 1 root root 216K Jan 17 01:46 1cross
# -rw-r--r-- 1 root root 679K Jan 17 01:46 2anm.pdb
# -rw-r--r-- 1 root root 7.1K Jan 17 01:46 2coor
# -rw-r--r-- 1 root root 216K Jan 17 01:46 2cross
# -rw-r--r-- 1 root root 679K Jan 17 01:46 3anm.pdb
# -rw-r--r-- 1 root root 7.1K Jan 17 01:46 3coor
# -rw-r--r-- 1 root root 216K Jan 17 01:46 3cross
# -rw-r--r-- 1 root root 679K Jan 17 01:46 4anm.pdb
# -rw-r--r-- 1 root root 142K Jan 17 01:46 4cln.pdb
# -rw-r--r-- 1 root root 7.1K Jan 17 01:46 4cln.pdb.1vector
# -rw-r--r-- 1 root root 7.1K Jan 17 01:46 4cln.pdb.2vector
# -rw-r--r-- 1 root root  273 Jan 17 01:46 4cln.pdb.hinge
# -rw-r--r-- 1 root root 107K Jan 17 01:46 4cln.pdb.mode1.pdb
# -rw-r--r-- 1 root root 107K Jan 17 01:46 4cln.pdb.mode2.pdb
# -rw-r--r-- 1 root root 9.6K Jan 17 01:46 4cln.pdb.new
# -rw-r--r-- 1 root root  480 Jan 17 01:46 4cln.pdb.new.hinges
# -rw-r--r-- 1 root root   35 Jan 17 01:46 4cln.pdb.new.loops
# -rw-r--r-- 1 root root 7.1K Jan 17 01:46 4coor
# -rw-r--r-- 1 root root 216K Jan 17 01:46 4cross
# -rw-r--r-- 1 root root 679K Jan 17 01:46 5anm.pdb
# -rw-r--r-- 1 root root 7.1K Jan 17 01:46 5coor
# -rw-r--r-- 1 root root 216K Jan 17 01:46 5cross
# -rw-r--r-- 1 root root 679K Jan 17 01:46 6anm.pdb
# -rw-r--r-- 1 root root 7.1K Jan 17 01:46 6coor
# -rw-r--r-- 1 root root 216K Jan 17 01:46 6cross
# -rw-r--r-- 1 root root 679K Jan 17 01:46 7anm.pdb
# -rw-r--r-- 1 root root 7.1K Jan 17 01:46 7coor
# -rw-r--r-- 1 root root 216K Jan 17 01:46 7cross
# -rw-r--r-- 1 root root 679K Jan 17 01:46 8anm.pdb
# -rw-r--r-- 1 root root 7.1K Jan 17 01:46 8coor
# -rw-r--r-- 1 root root 216K Jan 17 01:46 8cross
# -rw-r--r-- 1 root root 679K Jan 17 01:46 9anm.pdb
# -rw-r--r-- 1 root root 7.1K Jan 17 01:46 9coor
# -rw-r--r-- 1 root root 216K Jan 17 01:46 9cross
# -rw-r--r-- 1 root root 8.0K Jan 17 01:46 alpha.cor
# -rw-r--r-- 1 root root  18K Jan 17 01:46 anm_length
# -rw-r--r-- 1 root root 8.9K Jan 17 01:46 coor1.mds12
# -rw-r--r-- 1 root root 8.9K Jan 17 01:46 coor2.mds12
# -rw-r--r-- 1 root root 8.9K Jan 17 01:46 coor3.mds12
# -rw-r--r-- 1 root root 8.9K Jan 17 01:46 coor4.mds12
# -rw-r--r-- 1 root root 6.0K Jan 17 01:46 coordinates
# -rw-r--r-- 1 root root 386K Jan 17 01:46 crosscorr
# -rw-r--r-- 1 root root 2.7K Jan 17 01:46 crosscorrslow1
# -rw-r--r-- 1 root root 2.7K Jan 17 01:46 crosscorrslow2
# -rw-r--r-- 1 root root 258K Jan 17 01:46 fort.44
# -rw-r--r-- 1 root root  284 Jan 17 01:46 mapping.out
# -rw-r--r-- 1 root root 679K Jan 17 01:46 mod1
# -rw-r--r-- 1 root root 679K Jan 17 01:46 mod2
# -rw-r--r-- 1 root root 8.0K Jan 17 01:46 newcoordinat2.mds
# -rw-r--r-- 1 root root 142K Jan 17 01:46 pdb
# -rw-r--r-- 1 root root 2.5K Jan 17 01:46 slow12avg
# -rw-r--r-- 1 root root  19K Jan 17 01:46 sloweigenvectors
# -rw-r--r-- 1 root root  19K Jan 17 01:46 slowmodes
# -rw-r--r-- 1 root root 2.4K Jan 17 01:46 sortedeigen
# -rw-r--r-- 1 root root 685K Jan 17 01:46 upperhessian
# -rw-r--r-- 1 root root 260K Jan 17 01:46 .vwmatrix
